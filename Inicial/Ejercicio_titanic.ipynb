# %%
import pandas as pd
# import os
# print(os.getcwd()) or pwd 
# os.listdir()

# %%
fichero_cvs = pd.read_csv('/Users/Camila Bernales/Documents/datascience/udemyCourse/archivos/titanic.csv', header= None,  prefix = 'col-')
fichero_cvs
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b3d803d16f18> in <module>
# ----> 1 fichero_cvs = pd.read_csv('/Users/Camila Bernales/Documents/datascience/udemyCourse/archivos/titanic.csv', header= None,  prefix = 'col-')
#       2 fichero_cvs
#
# NameError: name 'pd' is not defined

# %%
col_names = ['a1','a2','a3','a4','a5','a6','a7','a8','a9','a10','a11','a12']

# %%
fichero_cvs = pd.read_csv('/Users/Camila Bernales/Documents/datascience/udemyCourse/archivos/titanic.csv', header= None,  names=col_names)
fichero_cvs
# Out:
#               a1        a2      a3  \
# 0    PassengerId  Survived  Pclass
# 1              1         0       3
# 2              2         1       1
# 3              3         1       3
# 4              4         1       1
# ..           ...       ...     ...
# 887          887         0       2
# 888          888         1       1
# 889          889         0       3
# 890          890         1       1
# 891          891         0       3
#
#                                                     a4      a5   a6     a7  \
# 0                                                 Name     Sex  Age  SibSp
# 1                              Braund, Mr. Owen Harris    male   22      1
# 2    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 3                               Heikkinen, Miss. Laina  female   26      0
# 4         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# ..                                                 ...     ...  ...    ...
# ...

# %%
fichero_cvs = pd.read_csv('/Users/Camila Bernales/Documents/datascience/udemyCourse/archivos/titanic.csv', header= 0)
fichero_cvs
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
fichero_cvs = pd.read_csv('/Users/Camila Bernales/Documents/datascience/udemyCourse/archivos/titanic.csv', header= 0, index_col = 3)
fichero_cvs
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-84c4ac9be648> in <module>
# ----> 1 fichero_cvs = pd.read_csv('/Users/Camila Bernales/Documents/datascience/udemyCourse/archivos/titanic.csv', header= 0, index_col = 3)
#       2 fichero_cvs
#
# NameError: name 'pd' is not defined

# %%
fichero_cvs = pd.read_csv('/Users/Camila Bernales/Documents/datascience/udemyCourse/archivos/titanic.csv', header= 0, usecols = [0,1,2,3,4])
fichero_cvs
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# ...

# %%
fichero_cvs = pd.read_csv('/Users/Camila Bernales/Documents/datascience/udemyCourse/archivos/titanic.csv', header= 0)
fichero_cvs.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
fichero_cvs = pd.read_csv('/Users/Camila Bernales/Documents/datascience/udemyCourse/archivos/titanic.csv', header= 0, dtype={'Survived':'bool'})
fichero_cvs.dtypes
# Out:
# PassengerId      int64
# Survived          bool
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object
